# %% [markdown]
# # Week 2 – Individual Assignment – Zhendong Long (Jayden)

# %% [markdown]
# ## Introduction
#
# In this project, I will engage the data of “Park and Ride Locations in LA County” and visualize the dataset on the map. The dataset was acquired from LA County GIS Data (https://egis-lacounty.hub.arcgis.com/datasets/6f6c4677365b4418bd585db2ef8e201f_187). It includes a total of 136 park and ride locations throughout LA County with the data of unique object ID number, owner, city location, and geo-location. The first set of steps I will do is to understand the dataset (how many data, what are the columns and rows, etc.). The second set of steps is to trim the data (produce the chart, rename the columns, eliminate columns with void values, etc.). Then I will have a clean and simplified dataset with the key information that I want to visualize. I will do the last set of steps to overlay the dataset on the base map and hence illustrate directly where each park and ride location is in the county.

# %% [markdown]
# ## Operation: Loading the module and file

# %%
# The first step is to import the module "Geopandas" and name it as "gpd"

import geopandas as gpd

# %%
# Then, I want to import my data set and make "Geopanda" read my shapefile.

# Then, I name this file as "parkandride"

parkandride = gpd.read_file('data/park and ride.shp')

# %% [markdown]
# **Operation Conclusion:**
#
# Through the two cells of code above, I am able to pull my data set into this python file and start explore it.

# %% [markdown]
# ## Operation: Understanding the dataset

# %%
# First, I want to know the data type:

type(parkandride)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# Then, I want to know how many rows and columns are in my data set:

parkandride.shape
# Out:
# (136, 30)

# %% [markdown]
# **Finding:** This means that there are 136 rows and 30 colums in my data set

# %%
# I want to know the overall information about my data set:

parkandride.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 30 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    136 non-null    int64
#  1   source      136 non-null    object
#  2   ext_id      0 non-null      object
#  3   cat1        136 non-null    object
#  4   cat2        136 non-null    object
#  5   cat3        0 non-null      object
#  6   org_name    136 non-null    object
#  7   Name        136 non-null    object
#  8   addrln1     1 non-null      object
#  9   addrln2     0 non-null      object
#  10  city        136 non-null    object
#  11  state       1 non-null      object
#  12  hours       0 non-null      object
#  13  phones      0 non-null      object
#  14  email       0 non-null      object
#  15  url         1 non-null      object
#  16  info1       0 non-null      object
#  17  info2       0 non-null      object
#  18  post_id     136 non-null    int64
#  19  descriptio  0 non-null      object
#  20  zip         0 non-null      object
#  21  link        136 non-null    object
#  22  use_type    136 non-null    object
#  23  latitude    136 non-null    float64
#  24  longitude   136 non-null    float64
#  25  date_updat  136 non-null    object
#  26  dis_status  0 non-null      object
#  27  POINT_X     136 non-null    float64
#  28  POINT_Y     136 non-null    float64
#  29  geometry    136 non-null    geometry
# dtypes: float64(4), geometry(1), int64(2), object(23)
# memory usage: 32.0+ KB

# %% [markdown]
# **Finding:** This is an overall info for my data set.
#
# 1. There are 30 columns and many of them have void values (e.g. hours, emails. etc).
# 2. Also, there are 136 valid values / park and ride locations

# %%
# Then, I want to know what my data set looks like in the form of chart:

parkandride.head()
# Out:
#    OBJECTID                                       source ext_id  \
# 0     60994  Metropolitan Transportation Authority (MTA)   None
# 1     60995  Metropolitan Transportation Authority (MTA)   None
# 2     60996  Metropolitan Transportation Authority (MTA)   None
# 3     60997  Metropolitan Transportation Authority (MTA)   None
# 4     60998  Metropolitan Transportation Authority (MTA)   None
#
#              cat1                     cat2  cat3  \
# 0  Transportation  Park and Ride Locations  None
# 1  Transportation  Park and Ride Locations  None
# 2  Transportation  Park and Ride Locations  None
# 3  Transportation  Park and Ride Locations  None
# 4  Transportation  Park and Ride Locations  None
#
#                                org_name                           Name  \
# 0  Metropolitan Transit Authority (MTA)         Glendora Park And Ride
# 1  Metropolitan Transit Authority (MTA)    Harbor Beacon Park And Ride
# 2  Metropolitan Transit Authority (MTA)  Artesia Station Park And Ride
# 3  Metropolitan Transit Authority (MTA)         Avenue S Park And Ride
# 4  Metropolitan Transit Authority (MTA)    Avenue S Park And Ride West
#
#   addrln1 addrln2  ...   zip                                    link use_type  \
# 0    None    None  ...  None  http://egis3.lacounty.gov/lms/?p=62865  publish
# 1    None    None  ...  None  http://egis3.lacounty.gov/lms/?p=62866  publish
# 2    None    None  ...  None  http://egis3.lacounty.gov/lms/?p=62867  publish
# 3    None    None  ...  None  http://egis3.lacounty.gov/lms/?p=62868  publish
# 4    None    None  ...  None  http://egis3.lacounty.gov/lms/?p=62869  publish
#
#     latitude   longitude  date_updat dis_status       POINT_X       POINT_Y  \
# 0  34.120953 -117.829503  2011-05-04       None  6.613274e+06  1.866441e+06
# 1  33.748036 -118.280145  2011-05-04       None  6.476503e+06  1.730803e+06
# 2  33.875358 -118.222867  2011-05-04       None  6.494019e+06  1.777095e+06
# 3  34.558300 -118.133033  2011-05-04       None  6.521617e+06  2.025583e+06
# 4  34.558309 -118.123993  2011-05-04       None  6.524339e+06  2.025583e+06
#
#                       geometry
# 0  POINT (-117.82950 34.12095)
# 1  POINT (-118.28014 33.74804)
# 2  POINT (-118.22287 33.87536)
# 3  POINT (-118.13303 34.55830)
# 4  POINT (-118.12399 34.55831)
#
# [5 rows x 30 columns]

# %%
# Then, I want to know how many park and ride site each city has:

parkandride['city'].value_counts()
# Out:
# Los Angeles              37
# Unincorporated           15
# Lancaster                 6
# Santa Clarita             6
# Glendora                  5
# Pomona                    5
# Palmdale                  4
# Baldwin Park              4
# Diamond Bar               3
# Covina                    3
# Downey                    3
# Agoura Hills              3
# Compton                   3
# Glendale                  3
# West Covina               3
# San Gabriel               3
# Hawthorne                 3
# Long Beach                3
# Norwalk                   2
# Industry                  2
# Commerce                  2
# Burbank                   2
# Rolling Hills Estates     1
# La Canada Flintridge      1
# Carson                    1
# Lynwood                   1
# Monrovia                  1
# La Verne                  1
# Claremont                 1
# Encino                    1
# Pasadena                  1
# Walnut                    1
# San Fernando              1
# El Monte                  1
# San Dimas                 1
# Torrance                  1
# La Mirada                 1
# Gardena                   1
# Name: city, dtype: int64

# %% [markdown]
# **Finding:**
#
# 1. Many cities only have few park and ride locations.
# 2. The city of LA has the most locations (37)

# %% [markdown]
# ## Operation: Visulize this finding in a graph:

# %%
# Save this series into a variable:

city_count = parkandride['city'].value_counts()

# then, I want to check if this variable is set successfully:

city_count
# Out:
# Los Angeles              37
# Unincorporated           15
# Lancaster                 6
# Santa Clarita             6
# Glendora                  5
# Pomona                    5
# Palmdale                  4
# Baldwin Park              4
# Diamond Bar               3
# Covina                    3
# Downey                    3
# Agoura Hills              3
# Compton                   3
# Glendale                  3
# West Covina               3
# San Gabriel               3
# Hawthorne                 3
# Long Beach                3
# Norwalk                   2
# Industry                  2
# Commerce                  2
# Burbank                   2
# Rolling Hills Estates     1
# La Canada Flintridge      1
# Carson                    1
# Lynwood                   1
# Monrovia                  1
# La Verne                  1
# Claremont                 1
# Encino                    1
# Pasadena                  1
# Walnut                    1
# San Fernando              1
# El Monte                  1
# San Dimas                 1
# Torrance                  1
# La Mirada                 1
# Gardena                   1
# Name: city, dtype: int64

# %%
# Then, convert this serire into a dataframe:

city_count = city_count.reset_index()

# Then, I want to check its output:

city_count
# Out:
#                     index  city
# 0             Los Angeles    37
# 1          Unincorporated    15
# 2               Lancaster     6
# 3           Santa Clarita     6
# 4                Glendora     5
# 5                  Pomona     5
# 6                Palmdale     4
# 7            Baldwin Park     4
# 8             Diamond Bar     3
# 9                  Covina     3
# 10                 Downey     3
# 11           Agoura Hills     3
# 12                Compton     3
# 13               Glendale     3
# 14            West Covina     3
# 15            San Gabriel     3
# 16              Hawthorne     3
# 17             Long Beach     3
# 18                Norwalk     2
# 19               Industry     2
# 20               Commerce     2
# 21                Burbank     2
# 22  Rolling Hills Estates     1
# 23   La Canada Flintridge     1
# 24                 Carson     1
# 25                Lynwood     1
# 26               Monrovia     1
# 27               La Verne     1
# 28              Claremont     1
# 29                 Encino     1
# 30               Pasadena     1
# 31                 Walnut     1
# 32           San Fernando     1
# 33               El Monte     1
# 34              San Dimas     1
# 35               Torrance     1
# 36              La Mirada     1
# 37                Gardena     1

# %%
# Rename the name of columns:

city_count.columns = ['City', 'Number of Park and Ride Site']

# then, I want to check if the names are updated:

city_count
# Out:
#                      City  Number of Park and Ride Site
# 0             Los Angeles                            37
# 1          Unincorporated                            15
# 2               Lancaster                             6
# 3           Santa Clarita                             6
# 4                Glendora                             5
# 5                  Pomona                             5
# 6                Palmdale                             4
# 7            Baldwin Park                             4
# 8             Diamond Bar                             3
# 9                  Covina                             3
# 10                 Downey                             3
# 11           Agoura Hills                             3
# 12                Compton                             3
# 13               Glendale                             3
# 14            West Covina                             3
# 15            San Gabriel                             3
# 16              Hawthorne                             3
# 17             Long Beach                             3
# 18                Norwalk                             2
# 19               Industry                             2
# 20               Commerce                             2
# 21                Burbank                             2
# 22  Rolling Hills Estates                             1
# 23   La Canada Flintridge                             1
# 24                 Carson                             1
# 25                Lynwood                             1
# 26               Monrovia                             1
# 27               La Verne                             1
# 28              Claremont                             1
# 29                 Encino                             1
# 30               Pasadena                             1
# 31                 Walnut                             1
# 32           San Fernando                             1
# 33               El Monte                             1
# 34              San Dimas                             1
# 35               Torrance                             1
# 36              La Mirada                             1
# 37                Gardena                             1

# %%
# then, I want to plot this chart into a graph:

city_count.plot()

# %%
# also, I have to name the elements of graph to make it clearer:

city_count.plot.bar(x = 'City', y = 'Number of Park and Ride Site', title = 'Park and Ride Infrastructure in LA County')

# %% [markdown]
# **Finding:** This graph directly present which cities have the park and ride facilities and which city has the most.

# %% [markdown]
# ## Operation: Triming the data set

# %%
# I want to trim the original data set before the next steps:

# I want to focus on the name

parkandride_trimmed = parkandride.drop(['source', 'ext_id', 'cat1','cat2','cat3','addrln1','addrln2','state','hours','phones', 'email', 'url', 'info1','info2', 'post_id','descriptio','zip','link', 'use_type','date_updat','dis_status','POINT_X','POINT_Y', 'geometry'], axis=1)

parkandride_trimmed
# Out:
#      OBJECTID                              org_name  \
# 0       60994  Metropolitan Transit Authority (MTA)
# 1       60995  Metropolitan Transit Authority (MTA)
# 2       60996  Metropolitan Transit Authority (MTA)
# 3       60997  Metropolitan Transit Authority (MTA)
# 4       60998  Metropolitan Transit Authority (MTA)
# ..        ...                                   ...
# 131     61126  Metropolitan Transit Authority (MTA)
# 132     61127  Metropolitan Transit Authority (MTA)
# 133     61128  Metropolitan Transit Authority (MTA)
# 134     61129  Metropolitan Transit Authority (MTA)
# 135     61130  Metropolitan Transit Authority (MTA)
#
#                                       Name            city   latitude  \
# 0                   Glendora Park And Ride        Glendora  34.120953
# 1              Harbor Beacon Park And Ride     Los Angeles  33.748036
# 2            Artesia Station Park And Ride         Compton  33.875358
# 3                   Avenue S Park And Ride        Palmdale  34.558300
# 4              Avenue S Park And Ride West        Palmdale  34.558309
# ..                                     ...             ...        ...
# 131               Vermont Av Park And Ride  Unincorporated  33.930204
# 132  Veterans Administration Park And Ride  Unincorporated  34.054491
# 133  Vincent Grade Metrolink Park And Ride  Unincorporated  34.499236
# 134     Washington & Fairfax Park And Ride     Los Angeles  34.034446
# 135          West Covina VFW Park And Ride     West Covina  34.069238
#
#       longitude
# 0   -117.829503
# 1   -118.280145
# 2   -118.222867
# 3   -118.133033
# 4   -118.123993
# ..          ...
# 131 -118.292502
# 132 -118.453956
# 133 -118.119095
# 134 -118.369190
# 135 -117.957569
#
# [136 rows x 6 columns]

# %%
parkandride_trimmed.columns = ['No','Owner','Site','City','Latitude','Longitude']

parkandride_trimmed
# Out:
#         No                                 Owner  \
# 0    60994  Metropolitan Transit Authority (MTA)
# 1    60995  Metropolitan Transit Authority (MTA)
# 2    60996  Metropolitan Transit Authority (MTA)
# 3    60997  Metropolitan Transit Authority (MTA)
# 4    60998  Metropolitan Transit Authority (MTA)
# ..     ...                                   ...
# 131  61126  Metropolitan Transit Authority (MTA)
# 132  61127  Metropolitan Transit Authority (MTA)
# 133  61128  Metropolitan Transit Authority (MTA)
# 134  61129  Metropolitan Transit Authority (MTA)
# 135  61130  Metropolitan Transit Authority (MTA)
#
#                                       Site            City   Latitude  \
# 0                   Glendora Park And Ride        Glendora  34.120953
# 1              Harbor Beacon Park And Ride     Los Angeles  33.748036
# 2            Artesia Station Park And Ride         Compton  33.875358
# 3                   Avenue S Park And Ride        Palmdale  34.558300
# 4              Avenue S Park And Ride West        Palmdale  34.558309
# ..                                     ...             ...        ...
# 131               Vermont Av Park And Ride  Unincorporated  33.930204
# 132  Veterans Administration Park And Ride  Unincorporated  34.054491
# 133  Vincent Grade Metrolink Park And Ride  Unincorporated  34.499236
# 134     Washington & Fairfax Park And Ride     Los Angeles  34.034446
# 135          West Covina VFW Park And Ride     West Covina  34.069238
#
#       Longitude
# 0   -117.829503
# 1   -118.280145
# 2   -118.222867
# 3   -118.133033
# 4   -118.123993
# ..          ...
# 131 -118.292502
# 132 -118.453956
# 133 -118.119095
# 134 -118.369190
# 135 -117.957569
#
# [136 rows x 6 columns]

# %% [markdown]
# **Finding:** For me, the name of each location, the owner, the geo-location are the most important information for me and the other information are eliminated because they are not useful in terms of my project goal.

# %% [markdown]
# ## Operation: Querying

# %%
# I want to know the list of park and ride sites within the city of "Los Angeles"

parkandride_trimmed.query("City == 'Los Angeles'")
# Out:
#         No                                 Owner  \
# 1    60995  Metropolitan Transit Authority (MTA)
# 5    60999  Metropolitan Transit Authority (MTA)
# 9    61003  Metropolitan Transit Authority (MTA)
# 10   61004  Metropolitan Transit Authority (MTA)
# 22   61017  Metropolitan Transit Authority (MTA)
# 28   61023  Metropolitan Transit Authority (MTA)
# 31   61026  Metropolitan Transit Authority (MTA)
# 41   61036  Metropolitan Transit Authority (MTA)
# 42   61037  Metropolitan Transit Authority (MTA)
# 44   61039  Metropolitan Transit Authority (MTA)
# 45   61040  Metropolitan Transit Authority (MTA)
# 46   61041  Metropolitan Transit Authority (MTA)
# 47   61042  Metropolitan Transit Authority (MTA)
# 54   61049  Metropolitan Transit Authority (MTA)
# 55   61050  Metropolitan Transit Authority (MTA)
# 56   61051  Metropolitan Transit Authority (MTA)
# 61   61056  Metropolitan Transit Authority (MTA)
# 62   61057  Metropolitan Transit Authority (MTA)
# 63   61058  Metropolitan Transit Authority (MTA)
# 77   61072  Metropolitan Transit Authority (MTA)
# 79   61074  Metropolitan Transit Authority (MTA)
# 96   61091  Metropolitan Transit Authority (MTA)
# 97   61092  Metropolitan Transit Authority (MTA)
# 103  61098  Metropolitan Transit Authority (MTA)
# 109  61104  Metropolitan Transit Authority (MTA)
# 114  61109  Metropolitan Transit Authority (MTA)
# 116  61111  Metropolitan Transit Authority (MTA)
# 117  61112  Metropolitan Transit Authority (MTA)
# 118  61113  Metropolitan Transit Authority (MTA)
# 119  61114  Metropolitan Transit Authority (MTA)
# 120  61115  Metropolitan Transit Authority (MTA)
# 121  61116  Metropolitan Transit Authority (MTA)
# 123  61118  Metropolitan Transit Authority (MTA)
# 124  61119  Metropolitan Transit Authority (MTA)
# 125  61120  Metropolitan Transit Authority (MTA)
# 129  61124  Metropolitan Transit Authority (MTA)
# 134  61129  Metropolitan Transit Authority (MTA)
# 121 -118.280615
# 123 -118.426817
# 124 -118.308704
# 125 -118.449799
# 129 -118.527710
# 134 -118.369190

# %% [markdown]
# **Finding:** The city of LA has the most park and ride locations in the county. By doing the query, I am able to see the entire list of LA city's locations.

# %% [markdown]
# ## Operation: Visualize all park and ride sites in LA county

# %%
# First, I want to visualize the data to get a sense what it may look like.

parkandride.plot()

# %%
# But, I want to viualize all sites on the base map - a real map:

# first, I need to load the module:

import folium

# then, default folium map:

m = folium.Map()

# then, I want to see it:

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# I want to find the center point of my sites:

# first, to find the average latitude: 

latitude = parkandride_trimmed.Latitude.mean()

# then, to find the average longitutde: 

longitude = parkandride_trimmed.Longitude.mean()

# %%
latitude
# Out:
# 34.114218906102934

# %%
longitude
# Out:
# -118.21010969066172

# %% [markdown]
# **Note:** This is the geo-location I want to put in the center of the map.

# %%
# Then, I want to zoom in the map at my center point:

m = folium.Map(location=[34.114218906102934, -118.21010969066172], zoom_start=10)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# I want to make markers for all sites:

# I have to create a for loop:

for index, row in parkandride_trimmed.iterrows():
    print(row.No, row.Site, row.City, row.Latitude, row.Longitude)
# Out:
# 60994 Glendora Park And Ride Glendora 34.12095286 -117.8295025
# 60995 Harbor Beacon Park And Ride Los Angeles 33.74803623 -118.2801447
# 60996 Artesia Station Park And Ride Compton 33.87535762 -118.2228666
# 60997 Avenue S Park And Ride Palmdale 34.55829981 -118.1330333
# 60998 Avenue S Park And Ride West Palmdale 34.55830937 -118.1239926
# 60999 Aviation Station Park And Ride Los Angeles 33.92950895 -118.3775226
# 61000 Baldwin Park Park And Ride Baldwin Park 34.08887345 -117.9549067
# 61001 Baldwin Park Metrolink Park And Ride Baldwin Park 34.08622835 -117.95744598
# 61002 Burbank Metrolink Station Park And Ride Burbank 34.17915508 -118.3135493
# 61003 Canoga Park Park And Ride Los Angeles 34.18928533 -118.6243151
# 61004 Chatsworth Metrolink Station Park And Ride Los Angeles 34.25242814 -118.6007621
# 61005 Citrus College Park And Ride Glendora 34.13144377 -117.882094
# 61006 Compton Station Park And Ride Compton 33.89596663 -118.2242098
# 61007 Covina Metrolink Park And Ride Covina 34.09268484 -117.8905975
# 61008 Del Amo Station Park And Ride Unincorporated 33.84703938 -118.2101519
# 61009 Diamond Bar Park And Ride Diamond Bar 34.02412478 -117.8118425
# 61010 Downey Park And Ride Downey 33.95689137 -118.1122204
# 61011 Eastland Park And Ride Covina 34.07658213 -117.8816265
# 61012 El Monte Metrolink Station Park And Ride El Monte 34.07663506 -118.0350094
# 61014 Encino Park And Ride Encino 34.16433493 -118.4920764
# 61015 Glendale East Park And Ride Glendale 34.14715992 -118.22979927
# 61016 Glendale Metrolink Park And Ride Glendale 34.12282743 -118.2584637
# 61017 Granada Hills Park And Ride Los Angeles 34.26464859 -118.479995
# 61018 Harbor Freeway Park And Ride Unincorporated 33.8314636 -118.287802
# 61019 Imperial Station Park And Ride Unincorporated 33.92866862 -118.2385609
