# %% [markdown]
# ## Week 2
#
# This is my week 2 assignment
#
# Add an introductory markdown cell with a title (header) and paragraph that describes what you are doing

# %%
# Import the module "Geopandas" and name it as "gpd"

import geopandas as gpd

# %%
# Import my data set and make "Geopanda" read this shapefile.

# Name this file as "parkandride"

parkandride = gpd.read_file('data/park and ride.shp')

# %% [markdown]
# 1st Conclusion:
#
# Through the two cells of code above, I am able to pull my data set into this python file and start explore it.

# %%
# I want to know the data type:

type(parkandride)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# I want to know how my data set look

# %%
# I want to know how many rows and columns are in my data set:

parkandride.shape
# Out:
# (136, 30)

# %% [markdown]
# Finding: This means that there are 136 rows and 30 colums in my data set

# %%
# I want to know the overall information about my data set:

parkandride.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 30 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    136 non-null    int64
#  1   source      136 non-null    object
#  2   ext_id      0 non-null      object
#  3   cat1        136 non-null    object
#  4   cat2        136 non-null    object
#  5   cat3        0 non-null      object
#  6   org_name    136 non-null    object
#  7   Name        136 non-null    object
#  8   addrln1     1 non-null      object
#  9   addrln2     0 non-null      object
#  10  city        136 non-null    object
#  11  state       1 non-null      object
#  12  hours       0 non-null      object
#  13  phones      0 non-null      object
#  14  email       0 non-null      object
#  15  url         1 non-null      object
#  16  info1       0 non-null      object
#  17  info2       0 non-null      object
#  18  post_id     136 non-null    int64
# ...

# %% [markdown]
# Finding:

# %%
# I want to know what my data set looks like in the form of chart:

parkandride.head()
# Out:
#    OBJECTID                                       source ext_id  \
# 0     60994  Metropolitan Transportation Authority (MTA)   None
# 1     60995  Metropolitan Transportation Authority (MTA)   None
# 2     60996  Metropolitan Transportation Authority (MTA)   None
# 3     60997  Metropolitan Transportation Authority (MTA)   None
# 4     60998  Metropolitan Transportation Authority (MTA)   None
#
#              cat1                     cat2  cat3  \
# 0  Transportation  Park and Ride Locations  None
# 1  Transportation  Park and Ride Locations  None
# 2  Transportation  Park and Ride Locations  None
# 3  Transportation  Park and Ride Locations  None
# 4  Transportation  Park and Ride Locations  None
#
#                                org_name                           Name  \
# 0  Metropolitan Transit Authority (MTA)         Glendora Park And Ride
# 1  Metropolitan Transit Authority (MTA)    Harbor Beacon Park And Ride
# ...

# %% [markdown]
# Finding:

# %%
# I want to know how many park and ride site each city has:

parkandride['city'].value_counts()
# Out:
# Los Angeles              37
# Unincorporated           15
# Santa Clarita             6
# Lancaster                 6
# Glendora                  5
# Pomona                    5
# Baldwin Park              4
# Palmdale                  4
# West Covina               3
# San Gabriel               3
# Downey                    3
# Diamond Bar               3
# Long Beach                3
# Glendale                  3
# Hawthorne                 3
# Covina                    3
# Agoura Hills              3
# Compton                   3
# Burbank                   2
# Industry                  2
# Commerce                  2
# Norwalk                   2
# San Fernando              1
# Walnut                    1
# La Mirada                 1
# Claremont                 1
# Carson                    1
# Torrance                  1
# Monrovia                  1
# Encino                    1
# Gardena                   1
# Lynwood                   1
# La Verne                  1
# ...

# %% [markdown]
# I want to visulize this finding in a graph:

# %%
# Save this series into a variable:

city_count = parkandride['city'].value_counts()

# then, I want to check if this variable is set successfully:

city_count
# Out:
# Los Angeles              37
# Unincorporated           15
# Santa Clarita             6
# Lancaster                 6
# Glendora                  5
# Pomona                    5
# Baldwin Park              4
# Palmdale                  4
# West Covina               3
# San Gabriel               3
# Downey                    3
# Diamond Bar               3
# Long Beach                3
# Glendale                  3
# Hawthorne                 3
# Covina                    3
# Agoura Hills              3
# Compton                   3
# Burbank                   2
# Industry                  2
# Commerce                  2
# Norwalk                   2
# San Fernando              1
# Walnut                    1
# La Mirada                 1
# Claremont                 1
# Carson                    1
# Torrance                  1
# Monrovia                  1
# Encino                    1
# Gardena                   1
# Lynwood                   1
# La Verne                  1
# ...

# %%
# Then, convert this serire into a dataframe:

city_count = city_count.reset_index()

# Then, I want to check its output:

city_count
# Out:
#                     index  city
# 0             Los Angeles    37
# 1          Unincorporated    15
# 2           Santa Clarita     6
# 3               Lancaster     6
# 4                Glendora     5
# 5                  Pomona     5
# 6            Baldwin Park     4
# 7                Palmdale     4
# 8             West Covina     3
# 9             San Gabriel     3
# 10                 Downey     3
# 11            Diamond Bar     3
# 12             Long Beach     3
# 13               Glendale     3
# 14              Hawthorne     3
# 15                 Covina     3
# 16           Agoura Hills     3
# 17                Compton     3
# 18                Burbank     2
# 19               Industry     2
# 20               Commerce     2
# 21                Norwalk     2
# 22           San Fernando     1
# 23                 Walnut     1
# 24              La Mirada     1
# 25              Claremont     1
# 26                 Carson     1
# 27               Torrance     1
# ...

# %%
# Rename the name of columns:

city_count.columns = ['City', 'Number of Park & Ride Site']

# then, I want to check if the names are updated:

city_count
# Out:
#                      City  Number of Park & Ride Site
# 0             Los Angeles                          37
# 1          Unincorporated                          15
# 2           Santa Clarita                           6
# 3               Lancaster                           6
# 4                Glendora                           5
# 5                  Pomona                           5
# 6            Baldwin Park                           4
# 7                Palmdale                           4
# 8             West Covina                           3
# 9             San Gabriel                           3
# 10                 Downey                           3
# 11            Diamond Bar                           3
# 12             Long Beach                           3
# 13               Glendale                           3
# 14              Hawthorne                           3
# 15                 Covina                           3
# ...

# %%
# then, I want to plot this chart into a graph:

city_count.plot()

# %%
# also, I have to name the elements of graph to make it clearer:

city_count.plot.bar(x = 'City', y = 'Number of Park & Ride Site', title = 'Park and Ride Infrastructure in LA County')

# %%
# I want to trim the original data set before the next steps:

# I want to focus on the name

parkandride_trimmed = parkandride.drop(['source', 'ext_id', 'cat1','cat2','cat3','addrln1','addrln2','state','hours','phones', 'email', 'url', 'info1','info2', 'post_id','descriptio','zip','link', 'use_type','date_updat','dis_status','POINT_X','POINT_Y', 'geometry'], axis=1)

parkandride_trimmed
# Out:
#      OBJECTID                              org_name  \
# 0       60994  Metropolitan Transit Authority (MTA)
# 1       60995  Metropolitan Transit Authority (MTA)
# 2       60996  Metropolitan Transit Authority (MTA)
# 3       60997  Metropolitan Transit Authority (MTA)
# 4       60998  Metropolitan Transit Authority (MTA)
# ..        ...                                   ...
# 131     61126  Metropolitan Transit Authority (MTA)
# 132     61127  Metropolitan Transit Authority (MTA)
# 133     61128  Metropolitan Transit Authority (MTA)
# 134     61129  Metropolitan Transit Authority (MTA)
# 135     61130  Metropolitan Transit Authority (MTA)
#
#                                       Name            city   latitude  \
# 0                   Glendora Park And Ride        Glendora  34.120953
# 1              Harbor Beacon Park And Ride     Los Angeles  33.748036
# 2            Artesia Station Park And Ride         Compton  33.875358
# ...

# %%
type(parkandride_trimmed)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# Convert this chart into an index:

parkandride_trimmed = parkandride_trimmed.reset_index()

type(parkandride_trimmed)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-9a7b57eed482> in <module>
#       1 # Convert this chart into an index:
#       2
# ----> 3 parkandride_trimmed2 = parkandride_trimmed.reset_index()
#       4
#       5 type(parkandride_trimmed2)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4602                 # to ndarray and maybe infer different dtype
#    4603                 level_values = _maybe_casted_values(lev, lab)
# -> 4604                 new_obj.insert(0, name, level_values)
#    4605
#    4606         new_obj.index = new_index
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
# ...

# %%
# I want to filter the graph to focus on the Park & Ride infrastructure in the City of LA:

# first, I want to make a copy of the original data set:

LA_City_parkandride = parkandride_trimmed.copy()

# then, I will filter the chart via query:

LA_City_parkandride.query ("City == 'Los Angeles'")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# /opt/conda/lib/python3.8/collections/__init__.py in __getitem__(self, key)
#     897                 pass
# --> 898         return self.__missing__(key)            # support subclasses that define __missing__
#     899
#
# /opt/conda/lib/python3.8/collections/__init__.py in __missing__(self, key)
#     889     def __missing__(self, key):
# --> 890         raise KeyError(key)
#     891
#
# KeyError: 'City'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
